# %% [raw]
# ---
# layout: post
# title: Introduction to Algorithms, Programming, and Compilers
# permalink: /mcqs/1/1
# author: Jacob Chou
# ---

# %% [markdown]
# ## Hack 1: Create Your Own Algorithm
#
# **Activity Chosen:** Making a pizza from scratch
# 1. Mix water, yeast, and sugar in a bowl
# 2. Add flour, olive oil, and salt
# 3. Stir mixture until a ball of dough forms
# 4. Knead the dough manually or with a mixture until smooth
# 5. Coat the dough in oil
# 6. Set the dough to rise in a warm spot or overnight in the fridge
# 7. Preheat oven to around 500 degrees F
# 8. Punch down and divide the dough.
# 9. Let the dough rest for 15 minutes
# 10. Press and stretch the ball into flat disks, leaving edges thick for the crust
# 11. Poke dents in the dough, and brush over with olive oil
# 12. Put douhg on baking sheet
# 13. Apply toppings like sauce, cheese, and apples
# 14. Bake the pizza for 10 to 15 minutes until the cheese bubbles
# 15. Enjoy!

# %% [markdown]
# ## Hack 2: Identify the Bug
#
# **Algorithm:** Send an Email
# 1. Open email application
# 2. Log into your account
# 3. Enter recipient's email address
# 4. Write subject line
# 5. Type the message
# 6. Click "Send"

# %% [markdown]
# ## Hack 3: Code the Algorithm
#
# **Algorithm** Grade Calculator

# %%
def calculate_grade(score1, score2, score3):
    """
    Calculate letter grade from three test scores

    Args: score1, score2, score3: Test scores (integers)
    
    Returns: Letter grade (string)
    """

    # Step 1: Add scores together
    sum = score1 + score2 + score3

    # Step 2: Calculate the average
    average = sum / 3

    # Step 3: Determine letter grade
    if average >= 90:
        grade = "A"
    elif average >= 80:
        grade = "B"
    elif average >= 70:
        grade = "C"
    elif average >= 60:
        grade = "D"
    else:
        grade = "F"
    
    # Step 4: Return the grade
    return grade

print("Test 1:", calculate_grade(95, 92, 88))  # Should be 'A'
print("Test 2:", calculate_grade(85, 80, 82))  # Should be 'B'
print("Test 3:", calculate_grade(75, 70, 72))  # Should be 'C'
print("Test 4:", calculate_grade(65, 60, 62))  # Should be 'D'
print("Test 5:", calculate_grade(55, 50, 52))  # Should be 'F'
# Out:
# Test 1: A
# Test 2: B
# Test 3: C
# Test 4: D
# Test 5: F
